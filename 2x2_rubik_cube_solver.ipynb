# %% [markdown]
# # 2x2 Rubik Cube Solver

# %% [markdown]
# # 1. Setting Up

# %% [markdown]
# ## 1.1. Libraries

# %%
# data manipulation
import numpy as np

# utilities
import random
import math
from queue import PriorityQueue

# images
from PIL import Image, ImageChops

# %% [markdown]
# ## 1.2. Constants

# %%
# U: Up
# F: Front
# R: Right
# L: Left
# B: Back
# D: Down
# Single quote (') means counterclockwise rotation (e.g. U' is up counterclockwise)
MOVES = ("U", "D", "R", "L", "F", "B", "U'", "D'", "R'", "L'", "F'", "B'")
MOVES_COLORS = {
    "U": 'yellow-right',
    "D": 'white-right',
    "R": 'blue-right',
    "L": 'green-right',
    "F": 'orange-right',
    "B": 'red-right',
    "U'": 'yellow-left',
    "D'": 'white-left',
    "R'": 'blue-left',
    "L'": 'green-left',
    "F'": 'orange-left',
    "B'": 'red-left',
}

# UUUU.DDDD.RRRR.LLLL.FFFF.BBBB (up.down.right.left.front.back)
# YYYY.WWWW.BBBB.GGGG.OOOO.RRRR (yellow.white.blue.green.orange.red)
SOLVED_CUBE = "YYYYWWWWBBBBGGGGOOOORRRR"

# Hexadecimal base colors
COLORS = {
    "Y": "#f6fe11",
    "G": "#08800c",
    "O": "#faaf0d",
    "B": "#0049e6",
    "R": "#f61109",
    "W": "#f0f0f0"
};

# %% [markdown]
# ## 1.3. Rotations

# %%
def rotate_cube(cube, move):
	if move not in MOVES:
		print(move)
		raise Exception('Mal movimiento de entrada')

	new_cube = list(cube)

	# UUUU.DDDD.RRRR.LLLL.FFFF.BBBB (up.down.right.left.front.back)
  # YYYY.WWWW.BBBB.GGGG.OOOO.RRRR (yellow.white.blue.green.orange.red)

	if move == "U":
		# sides
		# back -> right
		new_cube[8], new_cube[9] = cube[23], cube[22]
		# left -> back
		new_cube[23], new_cube[22] = cube[12], cube[13]
		# front -> left
		new_cube[12], new_cube[13] = cube[16], cube[17]
		# right -> front
		new_cube[16], new_cube[17] = cube[8], cube[9]
		# turn the top face
		new_cube[0], new_cube[1], new_cube[2], new_cube[3] = cube[2], cube[0], cube[3], cube[1]
	elif move == "D":
		# sides
		# back -> left
		new_cube[14], new_cube[15] = cube[20], cube[21]
		# left -> front
		new_cube[18], new_cube[19] = cube[14], cube[15]
		# front -> right
		new_cube[10], new_cube[11] = cube[18], cube[19]
		# right -> back
		new_cube[20], new_cube[21] = cube[10], cube[11]
		# turn the down face
		new_cube[4], new_cube[5], new_cube[6], new_cube[7] = cube[6], cube[4], cube[7], cube[5]
	elif move == "R":
		# sides
		# front -> top
		new_cube[3], new_cube[1] = cube[17], cube[19]
		# top -> back
		new_cube[23], new_cube[21] = cube[3], cube[1]
		# back -> bottom
		new_cube[7], new_cube[5] = cube[23], cube[21]
		# bottom -> front
		new_cube[17], new_cube[19] = cube[7], cube[5]
		# turn the right face
		new_cube[8], new_cube[9], new_cube[10], new_cube[11] = cube[10], cube[8], cube[11], cube[9]
	elif move == "L":
		# sides
		# front -> down
		new_cube[6], new_cube[4] = cube[18], cube[16]
		# top -> front
		new_cube[18], new_cube[16] = cube[2], cube[0]
		# back -> top
		new_cube[2], new_cube[0] = cube[22], cube[20]
		# down -> back
		new_cube[22], new_cube[20] = cube[6], cube[4]
		# turn the left face
		new_cube[12], new_cube[13], new_cube[14], new_cube[15] = cube[14], cube[12], cube[15], cube[13]
	elif move == "F":
		# sides
		# top -> right
		new_cube[8], new_cube[10] = cube[2], cube[3]
		# left -> up
		new_cube[2], new_cube[3] = cube[15], cube[13]
		# bottom -> left
		new_cube[15], new_cube[13] = cube[5], cube[4]
		# right -> down
		new_cube[5], new_cube[4] = cube[8], cube[10]
		# turn the front face
		new_cube[16], new_cube[17], new_cube[18], new_cube[19] = cube[18], cube[16], cube[19], cube[17]
	elif move == "B":
		# sides
		# top -> left
		new_cube[14], new_cube[12] = cube[0], cube[1]
		# left -> down
		new_cube[7], new_cube[6] = cube[14], cube[12]
		# down -> right
		new_cube[9], new_cube[11] = cube[7], cube[6]
		# right -> up
		new_cube[0], new_cube[1] = cube[9], cube[11]
		# turn the back face
		new_cube[20], new_cube[21], new_cube[22], new_cube[23] = cube[22], cube[20], cube[23], cube[21]
	elif move == "U'":
		# sides
		# right -> back
		new_cube[23], new_cube[22] = cube[8], cube[9]
		# back -> left
		new_cube[12], new_cube[13] = cube[23], cube[22]
		# left -> front
		new_cube[16], new_cube[17] = cube[12], cube[13]
		# front -> right
		new_cube[8], new_cube[9] = cube[16], cube[17]
		# turn the top face
		new_cube[2], new_cube[0], new_cube[3], new_cube[1] = cube[0], cube[1], cube[2], cube[3]
	elif move == "D'":
		# sides
		# left -> back
		new_cube[20], new_cube[21] = cube[14], cube[15]
		# front -> left
		new_cube[14], new_cube[15] = cube[18], cube[19]
		# right -> front
		new_cube[18], new_cube[19] = cube[10], cube[11]
		# back -> right
		new_cube[10], new_cube[11] = cube[20], cube[21]
		# turn the down face
		new_cube[6], new_cube[4], new_cube[7], new_cube[5] = cube[4], cube[5], cube[6], cube[7]
	elif move == "R'":
		# sides
		# top -> front
		new_cube[17], new_cube[19] = cube[3], cube[1]
		# back -> top
		new_cube[3], new_cube[1] = cube[23], cube[21]
		# down -> back
		new_cube[23], new_cube[21] = cube[7], cube[5]
		# front -> bottom
		new_cube[7], new_cube[5] = cube[17], cube[19]
		# turn the right face
		new_cube[10], new_cube[8], new_cube[11], new_cube[9] = cube[8], cube[9], cube[10], cube[11]
	elif move == "L'":
		# sides
		# bottom -> front
		new_cube[18], new_cube[16] = cube[6], cube[4]
		# front -> top
		new_cube[2], new_cube[0] = cube[18], cube[16]
		# top -> back
		new_cube[22], new_cube[20] = cube[2], cube[0]
		# back -> down
		new_cube[6], new_cube[4] = cube[22], cube[20]
		# turn the left face
		new_cube[14], new_cube[12], new_cube[15], new_cube[13] = cube[12], cube[13], cube[14], cube[15]
	elif move == "F'":
		# sides
		# right -> up
		new_cube[2], new_cube[3] = cube[8], cube[10]
		# top -> left
		new_cube[15], new_cube[13] = cube[2], cube[3]
		# left -> down
		new_cube[5], new_cube[4] = cube[15], cube[13]
		# down -> right
		new_cube[8], new_cube[10] = cube[5], cube[4]
		# turn the front face
		new_cube[18], new_cube[16], new_cube[19], new_cube[17] = cube[16], cube[17], cube[18], cube[19]
	elif move == "B'":
		# sides
		# left -> up
		new_cube[0], new_cube[1] = cube[14], cube[12]
		# down -> left
		new_cube[14], new_cube[12] = cube[7], cube[6]
		# right -> down
		new_cube[7], new_cube[6] = cube[9], cube[11]
		# top -> right
		new_cube[9], new_cube[11] = cube[0], cube[1]
		# turn the back face
		new_cube[22], new_cube[20], new_cube[23], new_cube[21] = cube[20], cube[21], cube[22], cube[23]

	return ''.join(new_cube)

# generate random cube
def random_cube(num_mov=10):
  cube = SOLVED_CUBE
  moves = []
  for _ in range(num_mov):
    # random.seed(0)
    move = MOVES[random.randint(0, len(MOVES) - 1)]
    moves.append(move)
    cube = rotate_cube(cube, move)
  return cube, moves

# For function cubeStr2Matrix
section_to_pos = {
    0: (2, 0),
    1: (2, 4),
    2: (4, 2),
    3: (0, 2),
    4: (2, 2),
    5: (6, 2),
}

# convert cube from string to matrix
def cubeStr2Matrix(cube):
  m = np.empty((6, 8), dtype='U')
  m[:] = ' '
  for i in range(len(cube)):
    sec = i // 4
    mod = i % 4
    x, y = section_to_pos[sec]
    if sec != 5:
      m[y + (mod >= 2)*1, x + (mod % 2)] = cube[i]
    else:
      m[(y + 1) - (mod >= 2)*1, (x + 1) - (mod % 2)] = cube[i]
  return m

# %% [markdown]
# ## 1.4. Image Reading

# %%
import math # import math module for mathematical operations

# hexadecimal to RGB conversion function
def hex_to_rgb(hex):
  if hex[0] == '#':
    hex = hex[1:]
  # return the resulting 3 integers representing RGB values
  return tuple(int(hex[i:i + 2], 16) for i in (0, 2, 4));

# function to calculate the distance between 2 colors in RGB space
def colors_dist(color1, color2):
  r1, g1, b1 = color1
  r2, g2, b2 = color2
  # calculate the Euclidean distance between the 2 colors in RGB space
  return math.sqrt((r1 - r2) ** 2 + (g1 - g2) ** 2 + (b1 - b2) ** 2)

# function to identify the most similar color from a list of predefined colors
def most_similar_color(color, margin):
  max_dist = math.sqrt(255 ** 2 + 255 ** 2 + 255 ** 2) # maximum possible distance between any 2 colors in RGB space
  min_dist = math.inf # set the minimum distance initially to infinity
  color_name = None # set the color name initially to None
  color1 = hex_to_rgb(color)
  # iterate through the predefined colors to find the most similar color
  for c_name in COLORS:
    color2 = hex_to_rgb(COLORS[c_name])
    dist = colors_dist(color1, color2)
    # compare the distance with the specified margin and the previous minimum distance
    if dist / max_dist < margin and dist < min_dist:
      # if the distance is less than the margin and less than the previous minimum distance, update the minimum distance and the name of the most similar color found so far
      min_dist = dist
      color_name = c_name
  return color_name # return the name of the most similar color found

# %%
# Eliminate image padding
# taken from https://stackoverflow.com/questions/10615901/trim-whitespace-using-pil/10616717#10616717
def trim(im):
  bg = Image.new(im.mode, im.size, im.getpixel((0,0)))
  diff = ImageChops.difference(im, bg)
  diff = ImageChops.add(diff, diff, 2.0, -100)
  bbox = diff.getbbox()
  return im.crop(bbox) if bbox else im

def read_image(file_path):
  image = Image.open(file_path)
  image = trim(image)
  image.show()

  # Get image size
  width, height = image.size

  # Get pixel matrix
  pixeles = image.load()

  # Dictionary of top-left corner positions for each face of the Rubik's cube
  # UUUU.DDDD.RRRR.LLLL.FFFF.BBBB (up.down.right.left.front.back)
  top_left_corners = {
      'U': (2, 0), # position in image matrix
      'D': (2, 4),
      'R': (4, 2),
      'L': (0, 2),
      'F': (2, 2),
      'B': (6, 2)
  }

  cube = ''
  # Iterate through each face of the cube
  for face_name in top_left_corners:
    # Get top-left position of the current face
    x, y = top_left_corners[face_name]
    # Reverse order of colors for back face
    rev = face_name == 'B'
    face = ''
    # Iterate through each pixel of the current face
    for i in range(2):
      for j in range(2):
        # Get color of current pixel and find the most similar color in our predefined list of colors
        color_pixel = pixeles[(x+j)*width/8+width/16, (y+i)*height/6+height/12]
        color = '#%02x%02x%02x' % (color_pixel[0], color_pixel[1], color_pixel[2])
        if not rev: # normal case
          face += most_similar_color(color, 10)
        else: # back face
          face = most_similar_color(color, 10) + face
    # Append the colors of the current face to the cube string
    cube += face
  return cube

# %% [markdown]
# # 2. Heuristic

# %% [markdown]
# ## 2.1. Heuristic Function

# %%
def heuristic1(cube):
    # Count the number of out-of-place tiles
  out_of_place = 0
  for i in range(len(cube)):
    if cube[i] != SOLVED_CUBE[i]:
      out_of_place += 1

  return out_of_place

def heuristic2(cube):
  # Calculate the Manhattan distance for each tile
  distance = 0
  for i in range(len(cube)):
    if cube[i] != SOLVED_CUBE[i]:
      distance += abs(i // 4 - SOLVED_CUBE.index(cube[i]) // 4) + abs(i % 4 - SOLVED_CUBE.index(cube[i]) % 4)
  return distance

def heuristic4(cube):
  # Define the solved corners permutation
  solved_corners = [(0, 2, 5), (0, 4, 7), (1, 3, 6), (1, 4, 6)]

  # Count the number of corners that are in the correct position relative to each other
  correct_corners = 0
  for corner in solved_corners:
    if all(cube[i] == SOLVED_CUBE[j] for i, j in zip(corner, corner)):
      correct_corners += 1

  # Returns the number of corners that are not in the correct position
  return 4 - correct_corners

def heuristic5(cube):
  # Count the number of edges that are not oriented correctly
  incorrect_edges = 0
  for i, j in [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]:
    if cube[i] != SOLVED_CUBE[i] and cube[j] != SOLVED_CUBE[j]:
      incorrect_edges += 1

  # Returns the number of edges that are not oriented correctly
  return incorrect_edges

# %% [markdown]
# ## 2.2. Solver Algorithm

# %%
# tree
class Node:
  def __init__(self, state, step, heur, dist, parent):
    self.state = state # estado del cubo
    self.step = step # movimiento que llevó a este nodo (None para la raíz)
    self.heur = heur # valor heurístico del nodo
    self.dist = dist # distancia o costo para llegar a este nodo desde la raíz
    self.children = [] # lista de hijos del nodo
    self.parent = parent # padre del nodo
    self.cost_func = heur + dist # función de costo

  def __str__(self):
    return str(self.step) + ': ' + self.state + ' (h=' + str(self.heur) + ', c=' + str(self.dist) + ')'

  # cadena de retorno para la vista de árbol
  def tree(self, level=0):
    ret = "\t" * level + str(self) + "\n"
    for child in self.children:
      ret += child.tree(level + 1)
    return ret

  # para comparar en la PriorityQueue
  def __lt__(self, other):
    return self.cost_func < other.cost_func

# búsqueda A*
def solve_cube(cube, max_it=10000, keep_searching=False):
  # Para salida en .txt
  # report = f'ESTADO INICIAL (h={})'
  report = 'RESULTS\n\n1. Algorithm Traversal\n(Note: s=current state, h=heuristic, d=distance)\n'

  # Raíz del árbol
  root = Node(cube, None, heuristic1(cube), 0, None)
  best_node = root
  report += f'INITIAL STATE:\ns = {root.state}\n'

  # Inicializar la cola de prioridad para la búsqueda (menor puntuación f -> mayor prioridad)
  queue = PriorityQueue()
  queue.put(root)

  # Para guardar estados visitados y no volver a ellos
  visited = set()

  # Contador de iteraciones
  num_it = 0

  # bucle principal de la búsqueda
  while not queue.empty() and num_it < max_it:
    num_it += 1;

    # Obtener el siguiente nodo de la cola de prioridad
    curr_node = queue.get()
    report += f'ITERATION {num_it}:\ns = {curr_node.state}, h = {curr_node.heur}, d = {curr_node.dist}\n'

    # Comprobar si el cubo está resuelto
    if curr_node.heur == 0:
      # report += 'SOLUTION FOUND\n'
      best_node = curr_node
      if not keep_searching: break

    # Genera todos los posibles nodos hijos
    report += 'Generating children...\n'
    for move in MOVES:
      new_cube = rotate_cube(curr_node.state, move)
      if new_cube not in visited:
        visited.add(new_cube)
        new_node = Node(new_cube, move, heuristic1(new_cube), curr_node.dist + 1, curr_node);
        report += f'Child: s = {new_cube}, cost_function = {new_node.cost_func}\n'
        curr_node.children.append(new_node)

        # Añade el nodo hijo a la cola de prioridad
        queue.put(new_node)

  return num_it, best_node, root, report

# %% [markdown]
# # 3. Input

# %%
# OPTION 1: FROM RANDOMLY GENERATED CUBE
# num_mov = 5 # number of random initial movements
# cube, random_moves = random_cube(num_mov)
# print('Randomly generated moves', random_moves)

# OPTION 2: FROM A PNG IMAGE
# Use site https://rubiks-cube-solver.com/2x2/ to take a screenshot of the cube. Save the image in the workspace.
img_path = 'cube.png' # image path
cube = read_image(img_path)

# %% [markdown]
# # 4. Output

# %%
# Input cube representation
cube
# Out:
# 'RBYOOROGBRBWYOGGBWYWWRGY'

# %%
max_it = 100000000; # Maximum number of iterations

# If keep_searching=True, then it will keep searching even if it has found a solution, in order to find a better one.
num_it, best_node, root, report = solve_cube(cube, max_it, keep_searching=False);

# %%
# Build the sequence of moves that solved the cube (from the end to the beginning; and then the other way around)
moves = []
states = []
if best_node.heur == 0:
  node = best_node
  while node.step is not None: # While the node is the root
    moves.append(node.step)
    states.append(node.state)
    node = node.parent
  moves.reverse()
  states.reverse()

  report += '\n2. Steps to Solve the Cube:\n'
  report += f'Initial state:\n{cubeStr2Matrix(root.state)}\n'
  for i in range(len(states)):
    report += f'{MOVES_COLORS[moves[i]]}:\n{cubeStr2Matrix(states[i])}\n'
else:
  report += '\n2. No Solution Found\n'

# %%
print('RESULTS:\n')

if best_node.heur == 0:
  print('Solution found')
  print(moves)
else:
  print('Solution not found:')

print('Heuristics taken:', num_it)
print('Lowest heuristic achieved:', best_node.heur)
print('Cost of the best node:', best_node.dist)
print('Nearest cube representation:', best_node.state)
# Out:
# RESULTS:
#
# Solution found
# ["L'", "B'", "R'"]
# Heuristics taken: 31
# Lowest heuristic achieved: 0
# Cost of the best node: 3
# Nearest cube representation: YYYYWWWWBBBBGGGGOOOORRRR

# %%
# REPORT

# Report will be saved on report.txt in the workspace
f = open('report.txt', 'w')
f.write(report)
f.close()

# %%
print(report)
# Out:
# RESULTS
#
# 1. Algorithm Traversal
# (Note: s=current state, h=heuristic, d=distance)
# INITIAL STATE:
# s = RBYOOROGBRBWYOGGBWYWWRGY
# ITERATION 1:
# s = RBYOOROGBRBWYOGGBWYWWRGY, h = 18, d = 0
# Generating children...
# Child: s = YROBOROGYGBWBWGGBRYWWROY, cost_function = 20
# Child: s = RBYOOOGRBRYWYOWRBWGGBWGY, cost_function = 23
# Child: s = RWYWOROYBBWRYOGGBGYRWBGO, cost_function = 20
# Child: s = WBGOBRYGBRBWGYGORWYWOROY, cost_function = 20
# Child: s = RBGOBBOGYROWYOGRYBWWWRGY, cost_function = 23
# Child: s = RWYOORYGBGBOBORGBWYWGWYR, cost_function = 20
# Child: s = BORYOROGBWBWYGGGYOYWWRRB, cost_function = 16
# Child: s = RBYORGOOBRWRYOYWBWBWGGGY, cost_function = 23
# Child: s = RRYYOWOWRWBBYOGGBOYBWRGG, cost_function = 15
# Child: s = BBYOWRGGBRBWOGYGOWOWRRYY, cost_function = 15
# Child: s = RBBBOGOGRROWYOGYWWBYWRGY, cost_function = 23
# Child: s = GYYOORWRBRBBOOGGBWYWRYWG, cost_function = 16
# ITERATION 2:
# s = RRYYOWOWRWBBYOGGBOYBWRGG, h = 14, d = 1
# Generating children...
# Child: s = YRYROWOWGGBBBOGGRWYBWROY, cost_function = 17
# Child: s = RRYYOOWWRWYBYOWRBOGGBBGG, cost_function = 20
# Child: s = RBYOOROGBRBWYOGGBWYWWRGY, cost_function = 20
# Child: s = WRGYBWYWRWBBGYGOROYBOROG, cost_function = 17
# Child: s = RRGOBROWYWYBYOGWYBBOWRGG, cost_function = 21
# Child: s = WBYYOWYGRWBORORGBOYBGWGR, cost_function = 19
# Child: s = RYRYOWOWBOBBGGGGYOYBWRWR, cost_function = 12
# Child: s = RRYYWWOORWWRYOYBBOBBGGGG, cost_function = 21
# Child: s = RRYGOBOOWBRBYOGGBYYRWWGW, cost_function = 21
# Child: s = BRYYWWGWRWBBOGYGOOOBRRYG, cost_function = 12
# Child: s = RRRBOGOWWWOBYYGYOBBYWRGG, cost_function = 21
# Child: s = GYYYOWBWRRBROOWGBOYBRGWG, cost_function = 17
# ITERATION 3:
# s = RYRYOWOWBOBBGGGGYOYBWRWR, h = 10, d = 2
# Generating children...
# Child: s = RYRYOOWWBOYBGGWRYOGGBBWR, cost_function = 17
# Child: s = RBROORORBBBOGGGGYWYWWYWY, cost_function = 20
# Child: s = WYWYYWYWBOBBGGGGRORBOROR, cost_function = 13
# Child: s = RYGGBBOWROYBGOGWYYBOWRWR, cost_function = 19
# Child: s = OBRYOWGGBWBOYGRGYOYBWWRR, cost_function = 18
# Child: s = YYRROWOWYOBBRWGGGGYBWROB, cost_function = 18
# Child: s = RYRYWWOOBOWRGGYBYOBBGGWR, cost_function = 18
# Child: s = RRRROBOOOBBBGGGGYYYYWWWW, cost_function = 20
# Child: s = YYYYWWWWBOBBGGGGOOOBRRRR, cost_function = 5
# Child: s = RYBBGGOWWOOBGYGROBYYWRWR, cost_function = 19
# Child: s = GGRYOWBOBRBYOGWGYOYBRRWW, cost_function = 18
# ITERATION 4:
# s = YYYYWWWWBOBBGGGGOOOBRRRR, h = 2, d = 3
# Generating children...
# Child: s = YYYYWWWWRRBBOOGGBOOBRRGG, cost_function = 12
# Child: s = YYYYWWWWBOOBGGRROOGGBBRR, cost_function = 12
# Child: s = YBYOWRWRBBBOGGGGOWOWRYRY, cost_function = 13
# Child: s = YYGGBBWWYOYBGWGWOOBORRRR, cost_function = 14
# Child: s = OBYYWWGGBWBWYGYGOOOBRRRR, cost_function = 13
# Child: s = YYYYWWWWOOBBRRGGGGOBRROB, cost_function = 13
# Child: s = YYYYWWWWBORRGGOBOOBBGGRR, cost_function = 13
# Child: s = YRYRWBWOOBBBGGGGOYOYRWRW, cost_function = 13
# Child: s = OYOYRWRWBOBBGGGGWOWBYRYR, cost_function = 14
# Child: s = YYBBGGWWWOWBGYGYOBOORRRR, cost_function = 14
# Child: s = GGYYWWBOBYBYWGWGOOOBRRRR, cost_function = 13
# ITERATION 5:
# s = BRYYWWGWRWBBOGYGOOOBRRYG, h = 10, d = 2
# Generating children...
# Child: s = YBYRWWGWGYBBOOYGRWOBRRGO, cost_function = 16
# Child: s = BRYYGWWWRWOBOGRROOYGBBYG, cost_function = 18
# Child: s = BRGGBRGWYWYBOWYWOOBORRYG, cost_function = 20
# Child: s = WBYYWWOYRWBGRGBGOOOBYRGR, cost_function = 15
# Child: s = RYBYWWGWOOBBGYYGOGOBRRWR, cost_function = 13
# Child: s = BRYYWWWGRWRROGOBOOBBYGYG, cost_function = 19
# Child: s = BRYGWBGOWBRBOGYGOYORRWYW, cost_function = 18
# Child: s = OROYRWYWRWBBGGOYWOGBBRYG, cost_function = 18
# Child: s = BRRBGGGWWWWBOYYYOBOORRYG, cost_function = 20
# Child: s = YOYYWWBWRBBRGGWGOOOBRGRY, cost_function = 11
# ITERATION 6:
# s = YOYYWWBWRBBRGGWGOOOBRGRY, h = 8, d = 3
# Generating children...
# Child: s = YYYOWWBWYRBROOWGRBOBRGGG, cost_function = 18
# Child: s = YOYYBWWWRBOBGGRGOOWGBRRY, cost_function = 13
# Child: s = YBYOWGBYBRRBGGWGOWOWRORY, cost_function = 16
# Child: s = RORYOWOWRBBRWGGGYOYBWGBY, cost_function = 19
# Child: s = YOGGBRBWYBYRGWWWOOBORGRY, cost_function = 19
# Child: s = OYYYWWBWOOBRYRWGGGOBRGBR, cost_function = 17
# Child: s = YOYYWWWBRBRGGGOBOOBRWGRY, cost_function = 16
# Child: s = YGYYWBBOBRRBGGWGOYOORWRW, cost_function = 14
# Child: s = OOOYRWRWRBBRGGGWWOBBYGYY, cost_function = 19
# Child: s = YORBGGBWWBWRGYWYOBOORGRY, cost_function = 19
# Child: s = WGYYWWRBRYBOBGWGOOOBGYRR, cost_function = 16
# ITERATION 7:
# s = YYYYWWWWRRBBOOGGBOOBRRGG, h = 8, d = 4
# Generating children...
# Child: s = YYYYWWWWGGBBBOGGRROBRROO, cost_function = 14
# Child: s = YYYYWWWWRROBOORRBOGGBBGG, cost_function = 19
# Child: s = YBYOWRWGBRBROOGGBWOWRYGY, cost_function = 19
# Child: s = RYGYBWOWRRBBGOGOYOYBWRWG, cost_function = 19
# Child: s = YYGOBRWWYRYBOWGWOBBORRGG, cost_function = 19
# Child: s = RBYYWWOGRWBWYOYGBOOBGRGR, cost_function = 19
# Child: s = YYYYWWWWRRRROOOBBOBBGGGG, cost_function = 20
# Child: s = YRYGWBWORBRBOOGGBYOYRWGW, cost_function = 19
# Child: s = BYOYRWGWRRBBOGOGWOWBYRYG, cost_function = 19
# Child: s = YYRBOGWWWRWBOYGYOBBORRGG, cost_function = 19
# Child: s = GOYYWWBRRYBYWOWGBOOBRGRG, cost_function = 19
# ITERATION 8:
# s = YYYYWWWWBOOBGGRROOGGBBRR, h = 8, d = 4
# Generating children...
# Child: s = YYYYWWWWBOGGGGBBOORROBRR, cost_function = 14
# Child: s = YGYOWBWROBBOGGRROWGWBYRY, cost_function = 19
# Child: s = BYRYOWGWBOOBRGRGYOYGWBWR, cost_function = 19
# Child: s = YYRGOBWWYOYBGWRWGOGOBBRR, cost_function = 19
# Child: s = OBYYWWGRBWOWYGYROOGGRBRB, cost_function = 19
# Child: s = YYYYWWWWOOOBRRRRGGGGBBOB, cost_function = 20
# Child: s = YBYRWGWOOBBOGGRROYGYBWRW, cost_function = 19
# Child: s = OYGYBWRWBOOBGRGRWOWGYBYR, cost_function = 19
# Child: s = YYBOGRWWWOWBGYRYOGOGBBRR, cost_function = 19
# Child: s = RGYYWWBOBYOYWGWROOGGBRBR, cost_function = 19
# ITERATION 9:
# s = WYWYYWYWBOBBGGGGRORBOROR, h = 10, d = 3
# Generating children...
# Child: s = WWYYYWYWROBBROGGBORBORGG, cost_function = 18
# Child: s = WYWYYYWWBORBGGORROGGBBOR, cost_function = 18
# Child: s = WBWOYRYRBBBOGGGGRWRWOYOY, cost_function = 21
# Child: s = WYGGBBYWWOYBGYGWRRBOOROR, cost_function = 20
# Child: s = OBWYYWGGBWBYYGWGRORBOORR, cost_function = 19
# Child: s = YYWWYWYWROBBROGGGGRBOROB, cost_function = 19
# Child: s = WYWYWWYYBOORGGRBROBBGGOR, cost_function = 19
# Child: s = WRWRYBYOOBBBGGGGRYRYOWOW, cost_function = 21
# Child: s = WYBBGGYWWOYBGYGWOBRROROR, cost_function = 20
# Child: s = GGWYYWBOBWBYYGWGRORBRROO, cost_function = 19
# ITERATION 10:
# s = YOYYBWWWRBOBGGRGOOWGBRRY, h = 9, d = 4
# Generating children...
# Child: s = YYYOBWWWYROBOORGRBWGBRGG, cost_function = 20
# Child: s = YOYYWBWWRBWGGGBROORGOBRY, cost_function = 17
# Child: s = YGYOBRWYORBBGGRGOWWWBORY, cost_function = 19
# Child: s = BORYOWWWRBOBRGGGYOYGBRWY, cost_function = 18
# Child: s = YOGGORWWYBYBGBRWWOGOBRRY, cost_function = 19
# Child: s = BBYYBWGRRWOWOGYGOOWGRBYR, cost_function = 20
# Child: s = OYYYBWWWOOOBYRRGGGWGBRBR, cost_function = 19
# Child: s = YRYYBGWOBBROGGRGOYWOBWRW, cost_function = 17
# Child: s = OOWYBWRWRBOBGGGRBOWGYRYY, cost_function = 19
# Child: s = YOROGGWWWBBBGYRYOGOWBRRY, cost_function = 18
# Child: s = RGYYBWBBRYOOWGWGOOWGRYBR, cost_function = 20
# ITERATION 11:
# s = YRYRWBWOOBBBGGGGOYOYRWRW, h = 9, d = 4
# Generating children...
# Child: s = YYRRWBWOWRBBOYGGOBOYRWGG, cost_function = 18
# Child: s = YRYRWWOBOBOYGGRWOYGGBBRW, cost_function = 20
# Child: s = YRGGBOWOYBRBGWGBOOYYRWRW, cost_function = 19
# Child: s = BBYRWBGGOOBWRGYGOYOYRRWW, cost_function = 20
# Child: s = RRYYWBWOOYBBWRGGGGOYRWBO, cost_function = 19
# Child: s = YRYRBOWWOBRWGGOYOYBBGGRW, cost_function = 20
# Child: s = YWYWWYWYBBOBGGGGORORRBRO, cost_function = 14
# Child: s = ORORRBROOBBBGGGGWYWYYWYW, cost_function = 22
# Child: s = YROBGGWOBBWBGRGYYYOORWRW, cost_function = 18
# Child: s = GGYRWBBBOYBRWGOGOYOYWWRR, cost_function = 20
# ITERATION 12:
# s = RYBYWWGWOOBBGYYGOGOBRRWR, h = 10, d = 3
# Generating children...
# Child: s = RYBYGWWWOOOBGYRROGYGBBWR, cost_function = 19
# Child: s = RBBGWRGRBOBOGYYGOWOWRYWY, cost_function = 20
# Child: s = RYWYOWOWOOBBYGGYRGBBWRGR, cost_function = 18
# Child: s = RYGYBOGWBOYBGWYWOOBGRRWR, cost_function = 17
# Child: s = OBBYWWGYOWBGYYRGOGOBWRRR, cost_function = 18
# Child: s = YYRBWWGWOGBBRWYGGYOBRROO, cost_function = 17
# Child: s = RYBYWWWGOORRGYOBOGBBYGWR, cost_function = 20
# Child: s = RRBRWBGGOBOBGYYGOYOYRWWW, cost_function = 20
# Child: s = OYOYRWWWOOBBYGGYWGGBRRBR, cost_function = 16
# Child: s = RYOBYGGWWOWBGYYBGBOORRWR, cost_function = 19
# Child: s = YGBYWWBOORBYGYWGOGOBRRRW, cost_function = 16
# ITERATION 13:
# s = GGYYWWBOBYBYWGWGOOOBRRRR, h = 9, d = 4
# Generating children...
# Child: s = YGYGWWBORRBYOOWGBYOBRRGW, cost_function = 20
# Child: s = GGYYBWOWBYOBWGRROOWGBYRR, cost_function = 18
# Child: s = GBYOWRBRBBYYWGWGOOOWRGRY, cost_function = 18
# Child: s = RGRYOWOOBYBYWWGGGOYBWRBR, cost_function = 20
# Child: s = GGGGBBBOYYYYWWWWOOBORRRR, cost_function = 22
# Child: s = GYGYWWBOOOBYRRWGWGOBRRYB, cost_function = 20
# Child: s = GGYYWOWBBYRRWGOBOOBYWGRR, cost_function = 19
# Child: s = GRYRWBBOYYBBWGWGOYOGRWRO, cost_function = 19
# Child: s = OGOYRWROBYBYGGWWWOBBGRYR, cost_function = 20
# Child: s = GGBBGGBOWYWYWYWYOBOORRRR, cost_function = 22
# Child: s = WWYYWWYYBGBGBGOGOOOBRRRR, cost_function = 14
# ITERATION 14:
# s = OBYYWWGGBWBWYGYGOOOBRRRR, h = 9, d = 4
# Generating children...
# Child: s = YOYBWWGGRRBWOOYGBWOBRRGY, cost_function = 20
# Child: s = OBYYGWGWBWOBYGRROOYGBWRR, cost_function = 18
# Child: s = OBYOWRGRBBWWYGYGOGOWRBRY, cost_function = 19
# Child: s = RBRYOWOGBWBWYYGGOOYBWRGR, cost_function = 19
# Child: s = OBGGBBGGYWYWYWYWOOBORRRR, cost_function = 22
# Child: s = BYOYWWGGOOBWRRYGYGOBRRWB, cost_function = 20
# Child: s = OBYYWGWGBWRRYGOBOOBWYGRR, cost_function = 19
# Child: s = ORYRWBGOWWBBYGYGOYOBRWRG, cost_function = 19
# Child: s = OBOYRWRGBWBWGGYYWOGBORYR, cost_function = 20
# Child: s = OBBBGGGGWWWWYYYYOBOORRRR, cost_function = 22
# ITERATION 15:
# s = YYYYWWWWOOBBRRGGGGOBRROB, h = 9, d = 4
# Generating children...
# Child: s = YBYGWRWBBOBORRGGGWOWRYOY, cost_function = 19
# Child: s = RYOYGWOWOOBBGRGRYGYBWRWB, cost_function = 20
# Child: s = YYGRBOWWYOYBRWGWOGBGRROB, cost_function = 20
# Child: s = OBYYWWRGOWBWYRYGGGOBORBR, cost_function = 20
# Child: s = YYYYWWWWOORRRROBGGBBGGOB, cost_function = 21
# Child: s = YRYBWBWGOBOBRRGGGYOYRWOW, cost_function = 19
# Child: s = GYOYRWOWOOBBRGRGWGWBYRYB, cost_function = 20
# Child: s = YYOBRGWWWOWBRYGYGBGORROB, cost_function = 20
# Child: s = GRYYWWBOOYBYWRWGGGOBRBRO, cost_function = 20
# ITERATION 16:
# s = YYYYWWWWBORRGGOBOOBBGGRR, h = 9, d = 4
# Generating children...
# Child: s = YBYOWGWRRBROGGOBOWBWGYRY, cost_function = 20
# Child: s = GYRYOWBWBORROGBGYOYBWGWR, cost_function = 20
# Child: s = YYBGRBWWYOYRGWOWBOBOGGRR, cost_function = 20
# Child: s = ORYYWWGOBWRWYGYBOOBBRGRG, cost_function = 19
# Child: s = YGYRWBWOORBRGGOBOYBYGWRW, cost_function = 20
# Child: s = OYBYGWRWBORRGBGOWOWBYGYR, cost_function = 20
# Child: s = YYBRGBWWWOWRGYOYOBOBGGRR, cost_function = 20
# Child: s = OGYYWWROBYRYWGWBOOBBGRGR, cost_function = 19
# ITERATION 17:
# s = YBYOWRWRBBBOGGGGOWOWRYRY, h = 9, d = 4
# Generating children...
# Child: s = YYOBWRWRYRBOOWGGBBOWRYGG, cost_function = 20
# Child: s = YBYOWWRRBBOWGGRYOWGGBORY, cost_function = 19
# Child: s = YBGGBBWRYBOOGWGROOWWRYRY, cost_function = 20
# Child: s = BOYOWRGGBRBWBGYGOWOWRRYY, cost_function = 19
# Child: s = BOYYWRWROWBOYRGGGGOWRYBB, cost_function = 20
# Child: s = YBYORRWWBBRYGGOWOWBOGGRY, cost_function = 18
# Child: s = OBOORRRRBBBOGGGGWWWWYYYY, cost_function = 22
# Child: s = YBBBGGWRRBWOGOGYWWOORYRY, cost_function = 20
# Child: s = GGYOWROBBYBBWGRGOWOWYYRR, cost_function = 18
# ITERATION 18:
# s = YGYYWBBOBRRBGGWGOYOORWRW, h = 10, d = 4
# Generating children...
# Child: s = YYYGWBBOWRRBOYWGBROORWGG, cost_function = 20
# Child: s = YGYYBWOBBROOGGRWOYWGRBRW, cost_function = 19
# Child: s = RGRYOBOOBRRBWGGGYYYOWWBW, cost_function = 22
# Child: s = YGGGRBBOYRYBGWWBOOOYRWRW, cost_function = 21
# Child: s = RBYYWBGWBORBGGYGOYOORRWW, cost_function = 15
# Child: s = GYYYWBBOOYRBWRWGGGOORWRB, cost_function = 19
# Child: s = YGYYBOWBBRRWGGOOOYRBWGRW, cost_function = 20
# Child: s = YWYWWOBYRBBRGGWGOYOGRBRO, cost_function = 17
# Child: s = OGOYRBROBRRBGGGWWYBOYWYW, cost_function = 22
# Child: s = YGBRGGBOBRWBGYWYYOOORWRW, cost_function = 20
# Child: s = WGYYWBBRBYRGBGOGOYOOWWRR, cost_function = 18
# ITERATION 19:
# s = YYYYWWWWGGBBBOGGRROBRROO, h = 9, d = 5
# Generating children...
# Child: s = YYYYWWWWGGOBBORRRRGGBBOO, cost_function = 21
# Child: s = YBYRWRWOBGBGBOGGRWOWRYOY, cost_function = 20
# Child: s = RYOYRWOWGGBBGBGOYRYBWRWO, cost_function = 21
# Child: s = YYGOBGWWYGYBBWGWORBRRROO, cost_function = 21
# Child: s = GBYYWWBGGWBWYOYGRROBOROR, cost_function = 21
# Child: s = YYYYWWWWGGRRBOOBRRBBGGOO, cost_function = 22
# Child: s = YRYOWBWRGBGBBOGGRYOYRWOW, cost_function = 20
# Child: s = RYOYRWOWGGBBOGBGWRWBYRYO, cost_function = 21
# Child: s = YYGBOGWWWGWBBYGYRBRORROO, cost_function = 21
# Child: s = GBYYWWBGGYBYWOWGRROBRORO, cost_function = 21
# ITERATION 20:
# s = YWYWWYWYBBOBGGGGORORRBRO, h = 9, d = 5
# Generating children...
# Child: s = YYWWWYWYOROBORGGBBORRBGG, cost_function = 21
# Child: s = YWYWWWYYBBORGGRBORGGOBRO, cost_function = 20
# Child: s = RWRWOYOYBBOBGGGGYRYRWBWO, cost_function = 23
# Child: s = YWGGOBWYYBWBGWGYOORRRBRO, cost_function = 20
# Child: s = BBYWWYGGBYOWWGYGORORRROB, cost_function = 21
# Child: s = WWYYWYWYOROBORGGGGORRBBB, cost_function = 21
# Child: s = YWYWYYWWBBRBGGOROROBGGRO, cost_function = 18
# Child: s = OWOWRYRYBBOBGGGGWRWRYBYO, cost_function = 23
# Child: s = YWBOGGWYYBWBGWGYRROORBRO, cost_function = 20
# Child: s = GGYWWYBBBYOWWGYGORORBORR, cost_function = 21
# ITERATION 21:
# s = OYOYRWRWBOBBGGGGWOWBYRYR, h = 10, d = 4
# Generating children...
# Child: s = OOYYRWRWRYBBWOGGBOWBYRGG, cost_function = 19
# Child: s = OYOYRRWWBOWBGGYRWOGGBBYR, cost_function = 19
# Child: s = OYGGBBRWOOYBGRGWWWBOYRYR, cost_function = 21
# Child: s = OBOYRWGGBWBRYGOGWOWBYYRR, cost_function = 20
# Child: s = YYOORWRWWOBBRYGGGGWBYROB, cost_function = 20
# Child: s = OYOYWWRRBOYRGGWBWOBBGGYR, cost_function = 20
# Child: s = OYBBGGRWWORBGYGOOBWWYRYR, cost_function = 21
# Child: s = GGOYRWBOBOBYRGWGWOWBRRYY, cost_function = 20
# ITERATION 22:
# s = YYBBGGWWWOWBGYGYOBOORRRR, h = 10, d = 4
# Generating children...
# Child: s = BYBYGGWWRRWBOBGYWOOORRYG, cost_function = 18
# Child: s = YYBBWGWGWOOOGYRROBGYWBRR, cost_function = 21
# Child: s = YOBBGRWRWWBOGYGYOWOGRYRB, cost_function = 20
# Child: s = RYRBOGOWWOWBGGYYYBBOGRWR, cost_function = 21
# Child: s = YBYBGGWWOBWBRRGYGYOORROW, cost_function = 18
# Child: s = YYBBGWGWWORRGYOOOBWBGYRR, cost_function = 21
# Child: s = YRBRGOWBOBWWGYGYOBOYRGRW, cost_function = 20
# Child: s = OYOBRGRWWOWBYYGGGBWOYRBR, cost_function = 21
# Child: s = YYWWYYWWGOGBGBGBBOOORRRR, cost_function = 15
# ITERATION 23:
# s = YYGGBBWWYOYBGWGWOOBORRRR, h = 10, d = 4
# Generating children...
# Child: s = GYGYBBWWRRYBOOGWYOBORRWG, cost_function = 19
# Child: s = YYGGWBWBYOBOGWRROOGWYBRR, cost_function = 19
# Child: s = YOGOBRWRYYBOGWGWOWBBRYRG, cost_function = 21
# Child: s = RYRGOBBWYOYBGGWWYOGOBRWR, cost_function = 20
# Child: s = YGYGBBWWOOYBRRGWGWBORROY, cost_function = 20
# Child: s = YYGGBWBWYORRGWBOOOYBGWRR, cost_function = 20
# Child: s = YRGRBOWOOBYYGWGWOGBYRBRW, cost_function = 21
# Child: s = OYBGRBRWYOYBWWGGBOWOYRGR, cost_function = 20
# ITERATION 24:
# s = YYYYWWWWBOGGGGBBOORROBRR, h = 9, d = 5
# Generating children...
# Child: s = YYYYWWWWRRGGOOBBBORROBGG, cost_function = 21
# Child: s = YRYOWBWRGBGOGGBBOWRWOYRY, cost_function = 21
# Child: s = OYRYOWRWBOGGBGBGYOYRWBWR, cost_function = 21
# Child: s = YYBGGBWWYOYGGWBWROROOBRR, cost_function = 21
# Child: s = OGYYWWGBBWGWYGYBOORRRORB, cost_function = 20
# Child: s = YYYYWWWWOOGGRRBBGGRROBOB, cost_function = 22
# Child: s = YBYRWRWOOGBGGGBBOYRYOWRW, cost_function = 21
# Child: s = OYRYOWRWBOGGGBGBWOWRYBYR, cost_function = 21
# Child: s = YYBGGBWWWOWGGYBYOROROBRR, cost_function = 21
# Child: s = BGYYWWGOBYGYWGWBOORRBROR, cost_function = 20
# ITERATION 25:
# s = WWYYWWYYBGBGBGOGOOOBRRRR, h = 9, d = 5
# Generating children...
# Child: s = YWYWWWYYRRBGOOOGBGOBRRGB, cost_function = 21
# Child: s = WWYYYWYWBGOBBGRROOOGBGRR, cost_function = 18
# Child: s = WBYOWRYRBBGGBGOGOYOWRWRY, cost_function = 20
# Child: s = RWRYOWOYBGBGOBGGWOYBWRYR, cost_function = 21
# Child: s = WWGGBBYYYGYGBWOWOOBORRRR, cost_function = 23
# Child: s = WYWYWWYYOOBGRROGBGOBRRGB, cost_function = 21
# Child: s = WWYYWYWYBGRRBGOBOOBGOGRR, cost_function = 20
# Child: s = WRYRWBYOGGBBBGOGOYOWRWRY, cost_function = 20
# Child: s = OWOYRWRYBGBGGGBOWOYBWRYR, cost_function = 21
# Child: s = WWBBGGYYWGWGBYOYOBOORRRR, cost_function = 23
# ITERATION 26:
# s = YYWWYYWWGOGBGBGBBOOORRRR, h = 10, d = 5
# Generating children...
# Child: s = WYWYYYWWRRGBBOGBGOOORRBG, cost_function = 19
# Child: s = YYWWWYWYGOOOGBRRBOGBGBRR, cost_function = 22
# Child: s = YOWOYRWRGGBOGBGBBWOYRYRW, cost_function = 22
# Child: s = RYRWBYOWGOGBGGBBYOWOYRWR, cost_function = 21
# Child: s = OBWWYYGGGWGWYBYBBOOORRRR, cost_function = 23
# Child: s = YWYWYYWWBOGBRRGBGBOORROG, cost_function = 19
# Child: s = YYWWYWYWGORRGBOOBOGBGBRR, cost_function = 22
# Child: s = YRWRYOWOOBGGGBGBBWOYRYRW, cost_function = 22
# Child: s = BYOWRYRWGOGBBBGGYOWOYRWR, cost_function = 21
# Child: s = GGWWYYBOGYGYWBWBBOOORRRR, cost_function = 23
# ITERATION 27:
# s = WBYYWWOYRWBGRGBGOOOBYRGR, h = 12, d = 3
# Generating children...
# Child: s = YWYBWWOYRGBGOOBGRWOBYRGR, cost_function = 19
# Child: s = WBYYOWYWRWOBRGYROOBGBGGR, cost_function = 19
# Child: s = WBYOWRORBRGWRGBGOYOWYBGY, cost_function = 21
# Child: s = YBGYOWOYRWBGBRGGWOYBWROR, cost_function = 19
# Child: s = WBGGBROYYWYGRWBWOOBOYRGR, cost_function = 23
# Child: s = BYWYWWOYOOBGRGBGRGOBYRWR, cost_function = 18
# Child: s = WBYYWYWORWYRRGOBOOBGBGGR, cost_function = 20
# Child: s = WRYRWBOOWGRBRGBGOYOBYWGY, cost_function = 21
# Child: s = OBOYYWGYRWBGGGRBWOOBWRYR, cost_function = 19
# Child: s = WBRBGGOYWWWGRYBYOBOOYRGR, cost_function = 23
# ITERATION 28:
# s = RBYYWBGWBORBGGYGOYOORRWW, h = 10, d = 5
# Generating children...
# Child: s = YRYBWBGWWWRBOYYGBOOORRGG, cost_function = 19
# Child: s = RBYYGWWBBOOOGGRROYYGRBWW, cost_function = 21
# Child: s = ROYYWRGWRBBOGGYGOWOBRBWY, cost_function = 18
# Child: s = RBWYOBOWBORBYGGGRYYOWRGW, cost_function = 21
# Child: s = RBGGRBGWYOYBGWYBOOOYRRWW, cost_function = 22
# Child: s = OBYYWBGYBWRGBGRGOYOOWRWR, cost_function = 19
# Child: s = BYRYWBGWOYRBWWYGGGOORROB, cost_function = 20
# Child: s = RBYYBWWGBORRGGOOOYRBYGWW, cost_function = 22
# Child: s = RRYWWOGYOBBRGGYGOYOBRBWW, cost_function = 20
# Child: s = OBOYRBWWBORBGGGYWYGORRYW, cost_function = 19
# Child: s = RBBRGGGWBOWBGYYYYOOORRWW, cost_function = 21
# ITERATION 29:
# s = BBYOWRGGBRBWOGYGOWOWRRYY, h = 14, d = 1
# Generating children...
# Child: s = YBOBWRGGYYBWOWYGBROWRRGO, cost_function = 19
# Child: s = BBYOGWGRBROWOGRROWYGBWYY, cost_function = 21
# Child: s = BWYWWRGYBBWROGYGOGORRBYO, cost_function = 17
# Child: s = BBGGBBGGYROWOWYROOWWRRYY, cost_function = 22
# Child: s = RWYOWROYBGBGBGBGOWOWYRYR, cost_function = 16
# Child: s = BOBYWRGGOWBWYYYGOGOWRRRB, cost_function = 17
# Child: s = BBYORGWGBRRROGOWOWBWYGYY, cost_function = 21
# Child: s = OBOORRYGBRBWGGOYWWGWBRYY, cost_function = 21
# Child: s = BBBBGGGGRRWWOOYYWWOORRYY, cost_function = 22
# Child: s = YOYOWRWRBBBBGGGGOWOWRYRY, cost_function = 10
# ITERATION 30:
# s = YOYOWRWRBBBBGGGGOWOWRYRY, h = 8, d = 2
# Generating children...
# Child: s = YYOOWRWRYRBBOWGGBBOWRYGG, cost_function = 17
# Child: s = YOYOWWRRBBOWGGRYOWGGBBRY, cost_function = 17
# Child: s = YWYWWYWYBBBBGGGGORORRORO, cost_function = 11
# Child: s = ROROORORBBBBGGGGYWYWWYWY, cost_function = 19
# Child: s = YOGGBBWRYBOBGWGROOWWRYRY, cost_function = 17
# Child: s = OOYYWRWROWBBYRGGGGOWRYBB, cost_function = 17
# Child: s = YOYORRWWBBRYGGOWOWBBGGRY, cost_function = 17
# Child: s = YYYYWWWWBBBBGGGGOOOORRRR, cost_function = 3
# Child: s = OOOORRRRBBBBGGGGWWWWYYYY, cost_function = 19
# Child: s = YOBBGGWRRBWBGOGYWWOORYRY, cost_function = 17
# Child: s = GGYOWRBBBYBOWGRGOWOWYYRR, cost_function = 17
# ITERATION 31:
# s = YYYYWWWWBBBBGGGGOOOORRRR, h = 0, d = 3
#
# 2. Steps to Solve the Cube:
# Initial state:
# [[' ' ' ' 'R' 'B' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'Y' 'O' ' ' ' ' ' ' ' ']
#  ['Y' 'O' 'B' 'W' 'B' 'R' 'Y' 'G']
#  ['G' 'G' 'Y' 'W' 'B' 'W' 'R' 'W']
#  [' ' ' ' 'O' 'R' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'O' 'G' ' ' ' ' ' ' ' ']]
# green-left:
# [[' ' ' ' 'B' 'B' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'Y' 'O' ' ' ' ' ' ' ' ']
#  ['O' 'G' 'O' 'W' 'B' 'R' 'Y' 'Y']
#  ['Y' 'G' 'O' 'W' 'B' 'W' 'R' 'R']
#  [' ' ' ' 'W' 'R' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'G' 'G' ' ' ' ' ' ' ' ']]
# red-left:
# [[' ' ' ' 'Y' 'O' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'Y' 'O' ' ' ' ' ' ' ' ']
#  ['G' 'G' 'O' 'W' 'B' 'B' 'Y' 'R']
#  ['G' 'G' 'O' 'W' 'B' 'B' 'Y' 'R']
#  [' ' ' ' 'W' 'R' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'W' 'R' ' ' ' ' ' ' ' ']]
# blue-left:
# [[' ' ' ' 'Y' 'Y' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'Y' 'Y' ' ' ' ' ' ' ' ']
#  ['G' 'G' 'O' 'O' 'B' 'B' 'R' 'R']
#  ['G' 'G' 'O' 'O' 'B' 'B' 'R' 'R']
#  [' ' ' ' 'W' 'W' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'W' 'W' ' ' ' ' ' ' ' ']]
